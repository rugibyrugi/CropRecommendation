# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn import tree
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/Crop_recommendation.csv")

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.tail()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee

# %%
df.size
# Out:
# 17600

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.isna().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
df.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
df['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# chickpea       100
# kidneybeans    100
# pigeonpeas     100
# mothbeans      100
# mungbean       100
# blackgram      100
# lentil         100
# pomegranate    100
# banana         100
# mango          100
# grapes         100
# watermelon     100
# muskmelon      100
# apple          100
# orange         100
# papaya         100
# coconut        100
# cotton         100
# jute           100
# coffee         100
# Name: count, dtype: int64

# %%
df['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
df.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# label           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.drop('label', axis=1).corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
# ##Separating features and target label

# %%
features = df[['N', 'P','K','temperature', 'humidity', 'ph', 'rainfall']]
target = df['label']
#features = df[['temperature', 'humidity', 'ph', 'rainfall']]
labels = df['label']

# %%
# Initialzing empty lists to append all model's name and corresponding name
acc = []
model = []

# %%
# Splitting into train and test data

from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(features,target,test_size = 0.2,random_state =2)

# %% [markdown]
# ##Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

DecisionTree = DecisionTreeClassifier(criterion="entropy",random_state=2,max_depth=5)

DecisionTree.fit(Xtrain,Ytrain)

predicted_values = DecisionTree.predict(Xtest)
x = metrics.accuracy_score(Ytest, predicted_values)
acc.append(x)
model.append('Decision Tree')
print("DecisionTrees's Accuracy is: ", x*100)

print(classification_report(Ytest,predicted_values))
# Out:
# DecisionTrees's Accuracy is:  90.0
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        13
#       banana       1.00      1.00      1.00        17
#    blackgram       0.59      1.00      0.74        16
#     chickpea       1.00      1.00      1.00        21
#      coconut       0.91      1.00      0.95        21
#       coffee       1.00      1.00      1.00        22
#       cotton       1.00      1.00      1.00        20
#       grapes       1.00      1.00      1.00        18
#         jute       0.74      0.93      0.83        28
#  kidneybeans       0.00      0.00      0.00        14
#       lentil       0.68      1.00      0.81        23
#        maize       1.00      1.00      1.00        21
#        mango       1.00      1.00      1.00        26
#    mothbeans       0.00      0.00      0.00        19
#     mungbean       1.00      1.00      1.00        24
#    muskmelon       1.00      1.00      1.00        23
# ...

# %%
from sklearn.model_selection import cross_val_score

# %%
# Cross validation score (Decision Tree)
score = cross_val_score(DecisionTree, features, target,cv=5)

# %%
score
# Out:
# array([0.93636364, 0.90909091, 0.91818182, 0.87045455, 0.93636364])

# %% [markdown]
# ##Saving trained decision tree model

# %%
import pickle
# Dump the trained decision tree model with Pickle
DT_pkl_filename = '/content/DecisionTree.pkl'
# Open the file to save as pkl file
DT_Model_pkl = open(DT_pkl_filename, 'wb')
pickle.dump(DecisionTree, DT_Model_pkl)
# Close the pickle instances
DT_Model_pkl.close()

# %% [markdown]
# ##Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

RandomForest = RandomForestClassifier(n_estimators=100, random_state=2)

RandomForest.fit(Xtrain,Ytrain)

predicted_values = RandomForest.predict(Xtest)
x = metrics.accuracy_score(Ytest, predicted_values)
acc.append(x)
model.append('Random Forest')
print("Random Forest's Accuracy is: ", x*100)

print(classification_report(Ytest,predicted_values))
# Out:
# Random Forest's Accuracy is:  99.54545454545455
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        13
#       banana       1.00      1.00      1.00        17
#    blackgram       1.00      1.00      1.00        16
#     chickpea       1.00      1.00      1.00        21
#      coconut       1.00      1.00      1.00        21
#       coffee       1.00      1.00      1.00        22
#       cotton       1.00      1.00      1.00        20
#       grapes       1.00      1.00      1.00        18
#         jute       0.93      1.00      0.97        28
#  kidneybeans       1.00      1.00      1.00        14
#       lentil       1.00      1.00      1.00        23
#        maize       1.00      1.00      1.00        21
#        mango       1.00      1.00      1.00        26
#    mothbeans       1.00      1.00      1.00        19
#     mungbean       1.00      1.00      1.00        24
# ...

# %% [markdown]
# ##Cross Validation Score (Random Forest)

# %%
score = cross_val_score(RandomForest,features,target,cv=5)

# %%
score
# Out:
# array([0.99318182, 0.99318182, 0.99545455, 0.99545455, 0.98636364])

# %% [markdown]
# ##Saving trained Random Forest Model

# %%
import pickle
# Dump the trained Random Forest model with Pickle
RF_pkl_filename = '/content/RandomForest.pkl'
# Open the file to save as pkl file
RF_Model_pkl = open(RF_pkl_filename, 'wb')
pickle.dump(RandomForest, RF_Model_pkl)
# Close the pickle instances
RF_Model_pkl.close()

# %% [markdown]
# ##Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

NaiveBayes = GaussianNB()

NaiveBayes.fit(Xtrain,Ytrain)

predicted_values = NaiveBayes.predict(Xtest)
x = metrics.accuracy_score(Ytest, predicted_values)
acc.append(x)
model.append('Naive Bayes')
print("Naive Bayes's Accuracy is: ", x)

print(classification_report(Ytest,predicted_values))
# Out:
# Naive Bayes's Accuracy is:  0.990909090909091
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        13
#       banana       1.00      1.00      1.00        17
#    blackgram       1.00      1.00      1.00        16
#     chickpea       1.00      1.00      1.00        21
#      coconut       1.00      1.00      1.00        21
#       coffee       1.00      1.00      1.00        22
#       cotton       1.00      1.00      1.00        20
#       grapes       1.00      1.00      1.00        18
#         jute       0.88      1.00      0.93        28
#  kidneybeans       1.00      1.00      1.00        14
#       lentil       1.00      1.00      1.00        23
#        maize       1.00      1.00      1.00        21
#        mango       1.00      1.00      1.00        26
#    mothbeans       1.00      1.00      1.00        19
#     mungbean       1.00      1.00      1.00        24
# ...

# %%
#Cross validation score (Gaussian Naive Bayes)
score = cross_val_score(NaiveBayes,features,target,cv=5)

# %%
score
# Out:
# array([0.99772727, 0.99545455, 0.99545455, 0.99545455, 0.99090909])

# %% [markdown]
# ##Saving trained Gaussian Naive Bayes Model

# %%
import pickle
#Dump the trained Naive Bayes classifier with pickle
NB_pkl_filename = '/content/NBClassifier.pkl'
# Open the file to save as pkl file
NB_Model_pkl = open(NB_pkl_filename, 'wb')
pickle.dump(NaiveBayes, NB_Model_pkl)
# Close the pickle instances
NB_Model_pkl.close()

# %% [markdown]
# ##Support Vector Machine

# %%
from sklearn.svm import SVC

SVM = SVC(gamma='auto')

SVM.fit(Xtrain,Ytrain)

predicted_values = SVM.predict(Xtest)
x = metrics.accuracy_score(Ytest, predicted_values)
acc.append(x)
model.append('SVM')
print("SVM's Accuracy is: ", x)

print(classification_report(Ytest,predicted_values))
# Out:
# SVM's Accuracy is:  0.10681818181818181
#               precision    recall  f1-score   support
#
#        apple       1.00      0.23      0.38        13
#       banana       1.00      0.24      0.38        17
#    blackgram       1.00      0.19      0.32        16
#     chickpea       1.00      0.05      0.09        21
#      coconut       1.00      0.05      0.09        21
#       coffee       0.00      0.00      0.00        22
#       cotton       1.00      0.05      0.10        20
#       grapes       1.00      0.06      0.11        18
#         jute       1.00      0.07      0.13        28
#  kidneybeans       0.03      1.00      0.07        14
#       lentil       0.00      0.00      0.00        23
#        maize       0.00      0.00      0.00        21
#        mango       0.00      0.00      0.00        26
#    mothbeans       0.00      0.00      0.00        19
#     mungbean       1.00      0.12      0.22        24
#    muskmelon       1.00      0.30      0.47        23
# ...

# %%
# Cross validation score (SVM)
score = cross_val_score(SVM,features,target,cv=5)

# %%
score
# Out:
# array([0.27727273, 0.28863636, 0.29090909, 0.275     , 0.26818182])

# %% [markdown]
# ##Saving trained Support Vector Machine Model

# %%
import pickle
#Dump the trained SVM classifier with pickle
SVM_pkl_filename = '/content/SVMClassifier.pkl'
# Open the file to save as pkl file
SVM_Model_pkl = open(SVM_pkl_filename, 'wb')
pickle.dump(SVM, SVM_Model_pkl)
# Close the pickle instances
SVM_Model_pkl.close()

# %% [markdown]
# ##XGBoost Model

# %%
#from xgboost import XGBClassifier

#XGB = XGBClassifier(objective='multi:softmax', n_estimators=100, random_state=2)

#XGB.fit(Xtrain,Ytrain)

#predicted_values = XGB.predict(Xtest)
#x = metrics.accuracy_score(Ytest, predicted_values)
#acc.append(x)
#model.append('XGBoost')
#print("XGBoost's Accuracy is: ", x*100)

#print(classification_report(Ytest,predicted_values))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1453553744.py in <cell line: 0>()
#       3 XGB = XGBClassifier(objective='multi:softmax', n_estimators=100, random_state=2)
#       4
# ----> 5 XGB.fit(Xtrain,Ytrain)
#       6
#       7 predicted_values = XGB.predict(Xtest)
#
# /usr/local/lib/python3.12/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     772             for k, arg in zip(sig.parameters, args):
#     773                 kwargs[k] = arg
# --> 774             return func(**kwargs)
#     775
#     776         return inner_f
#
# /usr/local/lib/python3.12/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1759                 or not (classes == expected_classes).all()
#    1760             ):
# ...

# %% [markdown]
# ### Cross Validation Score (XGBoost)
#
# ---

# %%
#score = cross_val_score(XGB,features,target,cv=5)
#score
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-600429845.py in <cell line: 0>()
# ----> 1 score = cross_val_score(XGB,features,target,cv=5)
#       2 score
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, error_score)
#     682     scorer = check_scoring(estimator, scoring=scoring)
#     683
# --> 684     cv_results = cross_validate(
# ...

# %% [markdown]
# ##Saving trained XGBoost Model

# %%
import pickle
# Dump the trained XGBoost model with Pickle
XGB_pkl_filename = '/content/XGBoost.pkl'
# Open the file to save as pkl file
XGB_Model_pkl = open(XGB_pkl_filename, 'wb')
pickle.dump(XGB, XGB_Model_pkl)
# Close the pickle instances
XGB_Model_pkl.close()

# %% [markdown]
# ##Accuracy Comparison

# %%
plt.figure(figsize=[10,5],dpi = 100)
plt.title('Accuracy Comparison')
plt.xlabel('Accuracy')
plt.ylabel('Algorithm')
sns.barplot(x = acc,y = model,palette='gist_rainbow_r')
# Out:
# <Axes: title={'center': 'Accuracy Comparison'}, xlabel='Accuracy', ylabel='Algorithm'>

# %%
accuracy_models = dict(zip(model, acc))
for k, v in accuracy_models.items():
    print (k, '-->', v)
# Out:
# Decision Tree --> 0.9
# Random Forest --> 0.9954545454545455
# Naive Bayes --> 0.990909090909091
# SVM --> 0.10681818181818181

# %% [markdown]
# ##Making a Prediction with Random Forest

# %%
import pandas as pd
import pickle

# Example new data point (replace with your actual data)
# N, P, K, temperature, humidity, ph, rainfall
new_data_point = pd.DataFrame([[90, 42, 43, 20.8, 82.0, 6.5, 202.9]], columns=['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall'])

# Load the trained Random Forest model
RF_pkl_filename = '/content/RandomForest.pkl'
with open(RF_pkl_filename, 'rb') as RF_Model_pkl:
    RandomForest_loaded = pickle.load(RF_Model_pkl)

# Make prediction
predicted_crop = RandomForest_loaded.predict(new_data_point)

print(f"The predicted crop for the given conditions is: {predicted_crop[0]}")
# Out:
# The predicted crop for the given conditions is: rice

# %% [markdown]
# ##Making a prediction with Decision Tree

# %%
import pandas as pd
import pickle

# Example new data point (replace with your actual data)
# N, P, K, temperature, humidity, ph, rainfall
new_data_point = pd.DataFrame([[90, 42, 43, 20.8, 82.0, 6.5, 202.9]], columns=['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall'])

# Load the trained Decision Tree model
DT_pkl_filename = '/content/DecisionTree.pkl'
with open(DT_pkl_filename, 'rb') as DT_Model_pkl:
    DecisionTree_loaded = pickle.load(DT_Model_pkl)

# Make prediction
predicted_crop = DecisionTree_loaded.predict(new_data_point)

print(f"The predicted crop for the given conditions is: {predicted_crop[0]}")
# Out:
# The predicted crop for the given conditions is: rice

# %% [markdown]
# ##Making a prediction with SVM Model

# %%
import pandas as pd
import pickle

# Example new data point (replace with your actual data)
# N, P, K, temperature, humidity, ph, rainfall
new_data_point = pd.DataFrame([[90, 42, 43, 20.8, 82.0, 6.5, 202.9]], columns=['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall'])

# Load the trained SVM model
SVM_pkl_filename = '/content/SVMClassifier.pkl'
with open(SVM_pkl_filename, 'rb') as SVM_Model_pkl:
    SVM_loaded = pickle.load(SVM_Model_pkl)

# Make prediction
predicted_crop = SVM_loaded.predict(new_data_point)

print(f"The predicted crop for the given conditions is: {predicted_crop[0]}")
# Out:
# The predicted crop for the given conditions is: rice

# %% [markdown]
# ##Making a prediction with Naive Bayes

# %%
import pandas as pd
import pickle

# Example new data point (replace with your actual data)
# N, P, K, temperature, humidity, ph, rainfall
new_data_point = pd.DataFrame([[90, 42, 43, 20.8, 82.0, 6.5, 202.9]], columns=['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall'])

# Load the trained Naive Bayes model
NB_pkl_filename = '/content/NBClassifier.pkl'
with open(NB_pkl_filename, 'rb') as NB_Model_pkl:
    NaiveBayes_loaded = pickle.load(NB_Model_pkl)

# Make prediction
predicted_crop = NaiveBayes_loaded.predict(new_data_point)

print(f"The predicted crop for the given conditions is: {predicted_crop[0]}")
# Out:
# The predicted crop for the given conditions is: rice
